# %% [markdown]
# ## Phase calculation: simple example ##
#
# Using gradient descent with momentum
#
# ### Sam's notes ###
#  - Might want to vary S as part of the optimisation, e.g. start with a tight Gaussian profile and grow.
#
# ### Tiff's notes ###
#  - Also want a conjugate gradient version!
#  - Currently just has a uniform S (laser field) - a very easy improvement will be to use a more realistic version (either a large Gaussian or an image of the real beam) - could either generate here or write a file with the targets (though not really necessary to produce a new file each time!)
#  - fftshift completely omitted - but will be easy to include!
#  - as in regions, would be good to extract target info from file names (or a useful text file in the folder) rather than entering manually
#  - at the moment, running for a defined number of iterations - would be useful to keep going until it stagnates
#  - Naming conventions for folders: need to find a good system otherwise things get very confusing very fast! Include everything to be able to get back to this result: random seed, cost function, number of iterations etc

# %% [markdown]
# ### Preamble; loading target and weighting arrays ###

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import theano

# %matplotlib inline


# decide what target you want:
targetdir = 'initialisation/example_power2_512_(350,350)_64/'
targetname = os.path.join(targetdir, 'target.dat')
# decide what weighting arrays to use:
weightingdir = os.path.join(targetdir, 'weighting_border_16_noise_1e-06/')
weightingname = os.path.join(weightingdir, 'weight.dat')
weightingASname = os.path.join(weightingdir, 'weight_as.dat')


target = np.loadtxt(targetname)
weighting = np.loadtxt(weightingname)
weighting_as = np.loadtxt(weightingASname)

N = target.shape[0]/2  # size of SLM is NxN (assuming that padding has doubled size here)

plot_args = {'extent':[0, 2*N, 0, 2*N],
             'interpolation':'None',
             'origin': 'lower'}

fig, axes = plt.subplots(ncols=2)
axes[0].imshow(target, vmin=0, vmax=1, **plot_args)
axes[0].set_title('Target')
axes[1].imshow(weighting, vmin=0, vmax=1, **plot_args)
axes[1].set_title('Weighting');

# %%
# Initialise SLM optimisation class:
import theano
import theano.tensor as T

# the code to set up the computation graph transforming the phases
# into an intensity field lives in the slmOptimisation class.
from slm import slmOptimisation

# initialise the phase:
def initial_phase(N):
    """ Return a randomised phase array over [0, 2pi]
    """
    return np.random.uniform(low=0, high=2*np.pi, size=(N,N)).astype(theano.config.floatX)

init_phi = initial_phase(N)

# for this example, the profile $S_{nm}$ is uniform.
s_profile = np.ones_like(init_phi, dtype=complex)  # NB in general s_profile may be complex.

slmOpt = slmOptimisation(target, init_phi, s_profile, A0=1.0/1000) # fudge factor! Need to stabilise this...

# %% [markdown]
# This is the crucial part, where we define the __cost__ function. Here we simply take the difference between the reconstruction and the target, square and sum.  Differentiation of this cost function happens automatically further downstream.
# $$ C = \sum_{nm} (T_{nm} - |E^{out}_{nm}|^2)^2 $$

# %%
# we now define a cost function to use, squared error for now.
cost = T.sum(T.pow((slmOpt.E_out_2 - target)*weighting, 2))

# visualise the output given the initial phi field
f_E_out = slmOpt.get_E_out()   # these return functions to evaluate the output
f_E2_out = slmOpt.get_intensity()

E_out = f_E_out()              # actually calculate the SLM output
E2_out = f_E2_out()

fig, (ax1a, ax1b, ax2) = plt.subplots(ncols=3, figsize=(15,15))
ax1a.imshow(E_out[0], vmin=0, vmax=3, **plot_args)
ax1a.set_title('E_out_r')
ax1b.imshow(E_out[1], vmin=0, vmax=3, **plot_args)
ax1b.set_title('E_out_i')
ax2.imshow(E2_out, vmin=0, vmax=3, **plot_args)
ax2.set_title('Intensity');

# %% [markdown]
# ### Stage 2 ###

# %%
import pandas as pd
from pandas import DataFrame

l_count = []
l_cost_SE = []
l_cost_AS = []
nn = 0  # global step-counting index

# %%
# new cost function:
cost_SE   = T.sum(T.pow((slmOpt.E_out_2 - target)*weighting, 2))
cost_AS_x =  T.sum(T.pow(slmOpt.E_out_2[0:2*N-1,:]-slmOpt.E_out_2[1:2*N,:], 2) * 20*weighting_as[0:2*N-1,:])
cost_AS_y =  T.sum(T.pow(  slmOpt.E_out_2[:,0:2*N-1]-slmOpt.E_out_2[:,1:2*N], 2) * 20*weighting_as[:,0:2*N-1])

cost = cost_SE #+ cost_AS_x + cost_AS_y
grad = T.grad(cost, wrt=slmOpt.phi)

l_rate = 0.01   # 'learning rate'
momentum = 0.95 # momentum decay
updates = ((slmOpt.phi, slmOpt.phi - l_rate * slmOpt.phi_rate),
           (slmOpt.phi_rate, momentum*slmOpt.phi_rate + (1.-momentum)*grad))

print "Compiling update function..."
update = theano.function([], 
                         cost, 
                         updates=updates,
                         on_unused_input='warn')
print "...done"

C = update()

f_cost_SE = theano.function([], cost_SE)
f_cost_AS = theano.function([], cost_AS_x + cost_AS_y)

f_phi_updates = theano.function([], l_rate*slmOpt.phi_rate)
# Out:
# Compiling update function...
# ...done

# %%
N_steps = 10000
print 'Initial C: {}'.format(C)
last_C = C
n = 0
for n in range(N_steps):
    C = update()
    nn += 1
    if np.mod(n, 100) == 0:
        c_SE = float(f_cost_SE())
        c_AS = float(f_cost_AS())
        l_cost_SE.append(c_SE)
        l_cost_AS.append(c_AS)
        l_count.append(nn)
        print '{step:d} Cost (SE):{cost_SE:.2e}   Cost (AS):{cost_AS:.2e}   Steps: mean:{update_step:.2e} max:{max_update_step:.2e}'.format(
            step=n,
            cost_SE=c_SE,
            cost_AS=c_AS,
            update_step=np.mean(np.abs(f_phi_updates())),
            max_update_step=np.max(np.abs(f_phi_updates()))
        )
        # print '{:d} {:.2e}'.format(n, float(C))

# make plots
E_out = f_E_out()
E2_out = f_E2_out()

fig, (ax1a, ax1b, ax2) = plt.subplots(ncols=3, figsize=(15,15))
ax1a.imshow(E_out[0], vmin=0, vmax=3, **plot_args)
ax1a.set_title('Re(E)')
ax1b.imshow(E_out[1], vmin=0, vmax=3, **plot_args)
ax1b.set_title('Im(E)')
ax2.imshow(E2_out, vmin=0, vmax=3, **plot_args)
ax2.set_title('Intensity');
# Out:
# Initial C: 170.409094947
# 0 Cost (SE):1.70e+02   Cost (AS):9.43e+03   Steps: mean:2.38e-05 max:1.26e-04
# 100 Cost (SE):1.58e+02   Cost (AS):8.70e+03   Steps: mean:1.07e-04 max:5.70e-04
# 200 Cost (SE):1.49e+02   Cost (AS):8.26e+03   Steps: mean:8.77e-05 max:5.45e-04
# 300 Cost (SE):1.42e+02   Cost (AS):8.02e+03   Steps: mean:7.66e-05 max:4.94e-04
# 400 Cost (SE):1.37e+02   Cost (AS):7.86e+03   Steps: mean:6.88e-05 max:4.40e-04
# 500 Cost (SE):1.33e+02   Cost (AS):7.73e+03   Steps: mean:6.29e-05 max:3.89e-04
# 600 Cost (SE):1.29e+02   Cost (AS):7.63e+03   Steps: mean:5.81e-05 max:3.44e-04
# 700 Cost (SE):1.26e+02   Cost (AS):7.53e+03   Steps: mean:5.42e-05 max:3.06e-04
# 800 Cost (SE):1.23e+02   Cost (AS):7.45e+03   Steps: mean:5.09e-05 max:2.73e-04
# 900 Cost (SE):1.20e+02   Cost (AS):7.37e+03   Steps: mean:4.81e-05 max:2.67e-04
# 1000 Cost (SE):1.18e+02   Cost (AS):7.30e+03   Steps: mean:4.56e-05 max:2.64e-04
# 1100 Cost (SE):1.16e+02   Cost (AS):7.24e+03   Steps: mean:4.36e-05 max:2.60e-04
# 1200 Cost (SE):1.14e+02   Cost (AS):7.17e+03   Steps: mean:4.18e-05 max:2.56e-04
# 1300 Cost (SE):1.12e+02   Cost (AS):7.11e+03   Steps: mean:4.02e-05 max:2.51e-04
# 1400 Cost (SE):1.11e+02   Cost (AS):7.06e+03   Steps: mean:3.89e-05 max:2.47e-04
# 1500 Cost (SE):1.09e+02   Cost (AS):7.00e+03   Steps: mean:3.78e-05 max:2.42e-04
# 1600 Cost (SE):1.08e+02   Cost (AS):6.95e+03   Steps: mean:3.68e-05 max:2.37e-04
# 1700 Cost (SE):1.06e+02   Cost (AS):6.89e+03   Steps: mean:3.58e-05 max:2.31e-04
# 1800 Cost (SE):1.05e+02   Cost (AS):6.84e+03   Steps: mean:3.49e-05 max:2.24e-04
# 1900 Cost (SE):1.04e+02   Cost (AS):6.79e+03   Steps: mean:3.40e-05 max:2.16e-04
# 2000 Cost (SE):1.03e+02   Cost (AS):6.75e+03   Steps: mean:3.30e-05 max:2.07e-04
# 2100 Cost (SE):1.02e+02   Cost (AS):6.70e+03   Steps: mean:3.19e-05 max:2.01e-04
# 2200 Cost (SE):1.01e+02   Cost (AS):6.66e+03   Steps: mean:3.07e-05 max:1.97e-04
# 2300 Cost (SE):9.98e+01   Cost (AS):6.62e+03   Steps: mean:2.95e-05 max:1.91e-04
# 2400 Cost (SE):9.89e+01   Cost (AS):6.58e+03   Steps: mean:2.83e-05 max:1.84e-04
# 2500 Cost (SE):9.82e+01   Cost (AS):6.55e+03   Steps: mean:2.72e-05 max:1.77e-04
# 2600 Cost (SE):9.74e+01   Cost (AS):6.51e+03   Steps: mean:2.62e-05 max:1.70e-04
# 2700 Cost (SE):9.67e+01   Cost (AS):6.48e+03   Steps: mean:2.53e-05 max:1.63e-04
# 2800 Cost (SE):9.61e+01   Cost (AS):6.45e+03   Steps: mean:2.44e-05 max:1.56e-04
# 2900 Cost (SE):9.55e+01   Cost (AS):6.43e+03   Steps: mean:2.37e-05 max:1.50e-04
# 3000 Cost (SE):9.49e+01   Cost (AS):6.40e+03   Steps: mean:2.29e-05 max:1.50e-04
# 3100 Cost (SE):9.44e+01   Cost (AS):6.38e+03   Steps: mean:2.22e-05 max:1.48e-04
# 3200 Cost (SE):9.39e+01   Cost (AS):6.36e+03   Steps: mean:2.16e-05 max:1.47e-04
# 3300 Cost (SE):9.34e+01   Cost (AS):6.34e+03   Steps: mean:2.09e-05 max:1.45e-04
# 3400 Cost (SE):9.29e+01   Cost (AS):6.32e+03   Steps: mean:2.03e-05 max:1.43e-04
# 3500 Cost (SE):9.25e+01   Cost (AS):6.30e+03   Steps: mean:1.98e-05 max:1.41e-04
# 3600 Cost (SE):9.21e+01   Cost (AS):6.28e+03   Steps: mean:1.93e-05 max:1.40e-04
# 3700 Cost (SE):9.17e+01   Cost (AS):6.26e+03   Steps: mean:1.88e-05 max:1.39e-04
# 3800 Cost (SE):9.14e+01   Cost (AS):6.24e+03   Steps: mean:1.85e-05 max:1.38e-04
# 3900 Cost (SE):9.10e+01   Cost (AS):6.23e+03   Steps: mean:1.81e-05 max:1.37e-04
# 4000 Cost (SE):9.07e+01   Cost (AS):6.21e+03   Steps: mean:1.78e-05 max:1.36e-04
# 4100 Cost (SE):9.03e+01   Cost (AS):6.20e+03   Steps: mean:1.76e-05 max:1.34e-04
# 4200 Cost (SE):9.00e+01   Cost (AS):6.18e+03   Steps: mean:1.74e-05 max:1.33e-04
# 4300 Cost (SE):8.97e+01   Cost (AS):6.17e+03   Steps: mean:1.72e-05 max:1.31e-04
# 4400 Cost (SE):8.94e+01   Cost (AS):6.15e+03   Steps: mean:1.69e-05 max:1.29e-04
# 4500 Cost (SE):8.91e+01   Cost (AS):6.14e+03   Steps: mean:1.67e-05 max:1.28e-04
# 4600 Cost (SE):8.88e+01   Cost (AS):6.13e+03   Steps: mean:1.64e-05 max:1.26e-04
# 4700 Cost (SE):8.85e+01   Cost (AS):6.11e+03   Steps: mean:1.60e-05 max:1.24e-04
# 4800 Cost (SE):8.83e+01   Cost (AS):6.10e+03   Steps: mean:1.56e-05 max:1.21e-04
# 4900 Cost (SE):8.80e+01   Cost (AS):6.09e+03   Steps: mean:1.52e-05 max:1.19e-04
# 5000 Cost (SE):8.78e+01   Cost (AS):6.08e+03   Steps: mean:1.48e-05 max:1.16e-04
# 5100 Cost (SE):8.76e+01   Cost (AS):6.07e+03   Steps: mean:1.44e-05 max:1.14e-04
# 5200 Cost (SE):8.74e+01   Cost (AS):6.06e+03   Steps: mean:1.40e-05 max:1.11e-04
# 5300 Cost (SE):8.72e+01   Cost (AS):6.05e+03   Steps: mean:1.36e-05 max:1.08e-04
# 5400 Cost (SE):8.70e+01   Cost (AS):6.04e+03   Steps: mean:1.33e-05 max:1.06e-04
# 5500 Cost (SE):8.68e+01   Cost (AS):6.03e+03   Steps: mean:1.29e-05 max:1.03e-04
# 5600 Cost (SE):8.66e+01   Cost (AS):6.02e+03   Steps: mean:1.27e-05 max:1.02e-04
# 5700 Cost (SE):8.64e+01   Cost (AS):6.02e+03   Steps: mean:1.24e-05 max:1.00e-04
# 5800 Cost (SE):8.63e+01   Cost (AS):6.01e+03   Steps: mean:1.22e-05 max:9.88e-05
# 5900 Cost (SE):8.61e+01   Cost (AS):6.00e+03   Steps: mean:1.19e-05 max:9.80e-05
# 6000 Cost (SE):8.60e+01   Cost (AS):6.00e+03   Steps: mean:1.17e-05 max:9.72e-05
# 6100 Cost (SE):8.58e+01   Cost (AS):5.99e+03   Steps: mean:1.15e-05 max:9.63e-05
# 6200 Cost (SE):8.57e+01   Cost (AS):5.98e+03   Steps: mean:1.13e-05 max:9.53e-05
# 6300 Cost (SE):8.56e+01   Cost (AS):5.98e+03   Steps: mean:1.12e-05 max:9.43e-05
# 6400 Cost (SE):8.54e+01   Cost (AS):5.97e+03   Steps: mean:1.10e-05 max:9.32e-05
# 6500 Cost (SE):8.53e+01   Cost (AS):5.97e+03   Steps: mean:1.09e-05 max:9.21e-05
# 6600 Cost (SE):8.52e+01   Cost (AS):5.96e+03   Steps: mean:1.07e-05 max:9.10e-05
# 6700 Cost (SE):8.51e+01   Cost (AS):5.96e+03   Steps: mean:1.06e-05 max:8.98e-05
# 6800 Cost (SE):8.49e+01   Cost (AS):5.95e+03   Steps: mean:1.04e-05 max:8.86e-05
# 6900 Cost (SE):8.48e+01   Cost (AS):5.95e+03   Steps: mean:1.03e-05 max:8.74e-05
# 7000 Cost (SE):8.47e+01   Cost (AS):5.94e+03   Steps: mean:1.02e-05 max:8.74e-05
# 7100 Cost (SE):8.46e+01   Cost (AS):5.94e+03   Steps: mean:1.01e-05 max:8.75e-05
# 7200 Cost (SE):8.45e+01   Cost (AS):5.94e+03   Steps: mean:9.96e-06 max:8.75e-05
# 7300 Cost (SE):8.44e+01   Cost (AS):5.93e+03   Steps: mean:9.86e-06 max:8.75e-05
# 7400 Cost (SE):8.43e+01   Cost (AS):5.93e+03   Steps: mean:9.76e-06 max:8.75e-05
# 7500 Cost (SE):8.42e+01   Cost (AS):5.92e+03   Steps: mean:9.66e-06 max:8.79e-05
# 7600 Cost (SE):8.41e+01   Cost (AS):5.92e+03   Steps: mean:9.56e-06 max:8.82e-05
# 7700 Cost (SE):8.40e+01   Cost (AS):5.92e+03   Steps: mean:9.47e-06 max:8.86e-05
# 7800 Cost (SE):8.39e+01   Cost (AS):5.91e+03   Steps: mean:9.39e-06 max:8.88e-05
# 7900 Cost (SE):8.38e+01   Cost (AS):5.91e+03   Steps: mean:9.30e-06 max:8.91e-05
# 8000 Cost (SE):8.37e+01   Cost (AS):5.90e+03   Steps: mean:9.22e-06 max:8.93e-05
# 8100 Cost (SE):8.36e+01   Cost (AS):5.90e+03   Steps: mean:9.14e-06 max:8.94e-05
# 8200 Cost (SE):8.35e+01   Cost (AS):5.90e+03   Steps: mean:9.07e-06 max:8.95e-05
# 8300 Cost (SE):8.34e+01   Cost (AS):5.89e+03   Steps: mean:8.99e-06 max:8.96e-05
# 8400 Cost (SE):8.34e+01   Cost (AS):5.89e+03   Steps: mean:8.92e-06 max:8.96e-05
# 8500 Cost (SE):8.33e+01   Cost (AS):5.89e+03   Steps: mean:8.85e-06 max:8.97e-05
# 8600 Cost (SE):8.32e+01   Cost (AS):5.88e+03   Steps: mean:8.79e-06 max:8.96e-05
# 8700 Cost (SE):8.31e+01   Cost (AS):5.88e+03   Steps: mean:8.72e-06 max:8.96e-05
# 8800 Cost (SE):8.30e+01   Cost (AS):5.88e+03   Steps: mean:8.66e-06 max:8.95e-05
# 8900 Cost (SE):8.29e+01   Cost (AS):5.87e+03   Steps: mean:8.60e-06 max:8.93e-05
# 9000 Cost (SE):8.29e+01   Cost (AS):5.87e+03   Steps: mean:8.54e-06 max:8.92e-05
# 9100 Cost (SE):8.28e+01   Cost (AS):5.87e+03   Steps: mean:8.48e-06 max:8.90e-05
# 9200 Cost (SE):8.27e+01   Cost (AS):5.87e+03   Steps: mean:8.43e-06 max:8.88e-05
# 9300 Cost (SE):8.26e+01   Cost (AS):5.86e+03   Steps: mean:8.37e-06 max:8.85e-05
# 9400 Cost (SE):8.26e+01   Cost (AS):5.86e+03   Steps: mean:8.32e-06 max:8.83e-05
# 9500 Cost (SE):8.25e+01   Cost (AS):5.86e+03   Steps: mean:8.28e-06 max:8.80e-05
# 9600 Cost (SE):8.24e+01   Cost (AS):5.85e+03   Steps: mean:8.23e-06 max:8.76e-05
# 9700 Cost (SE):8.23e+01   Cost (AS):5.85e+03   Steps: mean:8.18e-06 max:8.73e-05
# 9800 Cost (SE):8.23e+01   Cost (AS):5.85e+03   Steps: mean:8.14e-06 max:8.69e-05
# 9900 Cost (SE):8.22e+01   Cost (AS):5.84e+03   Steps: mean:8.10e-06 max:8.65e-05

# %%
fig, ax = plt.subplots(ncols=1, figsize=(6,6))
ax.imshow(E2_out[300:400,300:400], vmin=0, vmax=1, **plot_args)
ax.set_title('Intensity');

df = DataFrame({'idx': l_count, 'Cost (SE)': l_cost_SE, 'Cost (AS)': l_cost_AS})
# df.plot(marker='.')
fig2 = plt.figure(figsize=(5,5))
plt.gca().plot(df['idx'], df['Cost (SE)'], '.-')

# %%
print 'Mean update: {}'.format(np.mean(np.abs(f_phi_updates())))

phi_save = slmOpt.phi.get_value()
print phi_save
np.savetxt('phi.dat', phi_save)
# Out:
# Mean update: 9.26865436025e-05
# [[ -6.52210294   1.03031974 -10.88153478 ...,  -4.87587371   2.57411143
#    -2.37468936]
#  [ -9.26229696  -7.49448784  -1.91282482 ...,  -5.92705137  -6.45498751
#    -2.56682604]
#  [-10.48115263  -0.12721995  -9.15164717 ...,   3.97595629  -5.01954892
#    -5.75078323]
#  ...,
#  [ -5.75765927   4.31643364   6.09705432 ...,   1.76746246   6.63837868
#     7.26163563]
#  [  4.99943788   2.98625196   6.4994574  ...,  11.72882744   1.6380766
#     9.28811267]
#  [ -4.00867669  -5.20633456   5.93383231 ...,   3.07477638  -0.8162664
#     9.62548561]]

# %%
phi_save = np.loadtxt('phi.dat')
slmOpt.phi.set_value(phi_save)
